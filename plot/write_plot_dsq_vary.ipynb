# %%
library(reshape2)
library(ggplot2)
library(cowplot)

# %%
corr <- seq(.1, 1, 0.005)
mean_var_ratio <- seq(1, 10, 0.05)
K <- seq(3, 40)
seeds <- 1:100
# D <- seq(5, 50)

# %%
writefunc <- c()
for(seed in seeds) {
    for(i in corr) {
        writefunc <- rbind(writefunc, paste('module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R', i, seed))
    } 
    for(i in mean_var_ratio) {
        writefunc <- rbind(writefunc, paste('module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_mvr_dsq.R', i, seed))
    } 
    for(i in K) {
        writefunc <- rbind(writefunc, paste('module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R', i, seed))
    } 
}
# for(i in D) {
#     writefunc <- rbind(writefunc, paste('module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla vary_d_dsq.R', i))
# }
write.table(writefunc, file ='/home/bz234/Scripts/bash/CyTOF/dsq/vary_corr_mvr_k_d.txt', row.names = FALSE, col.names = FALSE, quote=FALSE)

# %%
writefunc
# Out:
#       [,1]
#  [1,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.1 1
#  [2,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.105 1
#  [3,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.11 1
#  [4,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.115 1
#  [5,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.12 1
#  [6,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.125 1
#  [7,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.13 1
#  [8,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.135 1
#  [9,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.14 1
# [10,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.145 1
# [11,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.15 1
# [12,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.155 1
# [13,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.16 1
# [14,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.165 1
# [15,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.17 1
# [16,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.175 1
# [17,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.18 1
# [18,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.185 1
# [19,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.19 1
# [20,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.195 1
# [21,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.2 1
# [22,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.205 1
# [23,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.21 1
# [24,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.215 1
# [25,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.22 1
# [26,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.225 1
# [27,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.23 1
# [28,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.235 1
# [29,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.24 1
# [30,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_corr_dsq.R 0.245 1
# [31,] ⋮
# [32,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 11 100
# [33,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 12 100
# [34,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 13 100
# [35,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 14 100
# [36,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 15 100
# [37,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 16 100
# [38,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 17 100
# [39,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 18 100
# [40,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 19 100
# [41,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 20 100
# [42,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 21 100
# [43,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 22 100
# [44,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 23 100
# [45,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 24 100
# [46,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 25 100
# [47,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 26 100
# [48,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 27 100
# [49,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 28 100
# [50,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 29 100
# [51,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 30 100
# [52,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 31 100
# [53,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 32 100
# [54,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 33 100
# [55,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 34 100
# [56,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 35 100
# [57,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 36 100
# [58,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 37 100
# [59,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 38 100
# [60,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 39 100
# [61,] module load miniconda; source activate r_env; cd /home/bz234/github/CyTOF_classification/; Rscript --vanilla ./plot/vary_k_dsq.R 40 100

# %%
files_mvr <- list()
for(i in 1:length(mean_var_ratio)) {
    files_mvr[[i]] <- paste0('/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_', mean_var_ratio[i], '.txt')
}
str(files_mvr)
# Out:
# List of 181
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.05.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.1.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.15.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.2.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.25.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.3.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.35.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.4.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.45.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.5.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.55.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.6.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.65.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.7.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.75.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.8.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.85.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.9.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.95.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.05.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.1.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.15.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.2.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.25.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.3.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.35.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.4.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.45.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.5.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.55.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.6.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.65.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.7.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.75.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.8.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.85.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.9.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.95.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.05.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.1.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.15.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.2.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.25.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.3.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.35.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.4.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.45.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.5.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.55.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.6.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.65.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.7.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.75.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.8.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.85.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.9.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.95.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.05.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.1.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.15.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.2.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.25.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.3.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.35.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.4.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.45.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.5.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.55.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.6.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.65.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.7.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.75.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.8.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.85.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.9.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.95.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.05.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.1.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.15.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.2.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.25.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.3.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.35.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.4.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.45.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.5.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.55.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.6.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.65.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.7.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.75.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.8.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.85.txt"
#  $ : chr "/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.9.txt"
#   [list output truncated]

# %%
files_corr <- list()
for(i in 1:length(corr)) {
    files_corr[[i]] <- paste0('/home/bz234/project/Results/CyTOF/simulation/vary_corr/s2_corr_', corr[i], '.txt')
}

# %%
files_k
# Out:
# [[1]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_3.txt"
#
# [[2]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_4.txt"
#
# [[3]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_5.txt"
#
# [[4]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_6.txt"
#
# [[5]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_7.txt"
#
# [[6]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_8.txt"
#
# [[7]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_9.txt"
#
# [[8]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_10.txt"
#
# [[9]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_11.txt"
#
# [[10]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_12.txt"
#
# [[11]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_13.txt"
#
# [[12]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_14.txt"
#
# [[13]]
# [1] "/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_15.txt"

# %%
files_k <- list()
for(i in 1:length(K)) {
    files_k[[i]] <- paste0('/home/bz234/project/Results/CyTOF/simulation/vary_k/s2_k_', K[i], '.txt')
}

# %%
files_d <- list()
for(i in 1:length(D)) {
    files_d[[i]] <- paste0('/home/bz234/project/Results/CyTOF/simulation/vary_d/s2_d_', D[i], '.txt')
}

# %%
read_error <- function (file) {
  return(tryCatch(read.table(file, header = TRUE), error=function(e) NULL))
}

# %%
table_lst_mvr <- lapply(files_mvr, read_error)
table_lst_mvr
# Out:
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.05.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.1.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.15.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.2.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.25.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.3.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.35.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.4.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.45.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.5.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.55.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.6.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.65.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.7.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.75.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.8.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.85.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.9.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_1.95.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.05.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.1.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.15.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.2.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.25.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.3.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.35.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.4.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.45.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.5.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.55.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.6.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.65.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.7.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.75.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.8.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.85.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.9.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_2.95.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.05.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.1.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.15.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.2.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.25.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.3.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.35.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.4.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.45.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.5.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.55.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.6.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.65.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.7.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.75.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.8.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.85.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.9.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_3.95.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.05.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.1.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.15.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.2.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.25.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.3.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.35.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.4.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.45.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.5.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.55.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.6.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.65.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.7.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.75.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.8.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.85.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.9.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_4.95.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.05.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.1.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.15.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.2.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.25.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.3.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.35.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.4.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.45.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.5.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.55.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.6.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5.65.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/s2_mvr_5
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_d/s2_d_5.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_d/s2_d_7.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_d/s2_d_8.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_d/s2_d_11.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_d/s2_d_12.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_d/s2_d_17.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_d/s2_d_19.txt': No such file or directory”
# Warning message in file(file, "rt"):
# “cannot open file '/home/bz234/project/Results/CyTOF/simulation/vary_d/s2_d_50.txt': No such file or directory”

# %%
results_lst_mvr <- matrix(, nrow = length(files_mvr), ncol = 5)
colnames(results_lst_mvr) <- c('mean_var_ratio', rownames(table_lst_mvr[[1]]))
results_lst_mvr[,1] <- mean_var_ratio
for(i in 1:length(files_mvr)) {
    if(is.null(table_lst_mvr[[i]]$x)){
        results_lst_mvr[i,2:5] <- NA
    } else{
    results_lst_mvr[i,2:5] <- table_lst_mvr[[i]]$x
    }
}
# Out:
# Error in matrix(, nrow = length(files_mvr), ncol = 5): object 'files_mvr' not found
# Traceback:
#
# 1. matrix(, nrow = length(files_mvr), ncol = 5)

# %%
results_lst_corr <- matrix(, nrow = length(files_corr), ncol = 5)
colnames(results_lst_corr) <- c('corr', rownames(table_lst_corr[[1]]))
results_lst_corr[,1] <- corr
for(i in 1:length(files_corr)) {
    if(is.null(table_lst_corr[[i]]$x)){
        results_lst_corr[i,2:5] <- NA
    } else{
    results_lst_corr[i,2:5] <- table_lst_corr[[i]]$x
    }
}

# %%
results_lst_corr[60:150,]
# Out:
#       corr  accu     cos_sim   ari       nmi
#  [1,] 0.395 0.994000 0.9638580 0.9840566 0.9942853
#  [2,] 0.400 0.987070 0.9538327 0.9696960 0.9876849
#  [3,] 0.405 0.987070 0.9538177 0.9696960 0.9876849
#  [4,] 0.410 0.987070 0.9537574 0.9696960 0.9876849
#  [5,] 0.415 0.993035 0.9648372 0.9819003 0.9933662
#  [6,] 0.420 0.993040 0.9648460 0.9819137 0.9933710
#  [7,] 0.425 0.993040 0.9648533 0.9819137 0.9933710
#  [8,] 0.430 0.993040 0.9648608 0.9819137 0.9933710
#  [9,] 0.435 0.993040 0.9648677 0.9819137 0.9933710
# [10,] 0.440 0.993040 0.9648743 0.9819137 0.9933710
# [11,] 0.445 0.993040 0.9648803 0.9819137 0.9933710
# [12,] 0.450 0.993040 0.9648861 0.9819137 0.9933710
# [13,] 0.455 0.993040 0.9648914 0.9819137 0.9933710
# [14,] 0.460 0.993040 0.9648972 0.9819137 0.9933710
# [15,] 0.465 0.993040 0.9649017 0.9819137 0.9933710
# [16,] 0.470 0.993040 0.9649056 0.9819137 0.9933710
# [17,] 0.475 0.993040 0.9649103 0.9819137 0.9933710
# [18,] 0.480 0.992545 0.9639755 0.9806605 0.9928995
# [19,] 0.485 0.992545 0.9639937 0.9806605 0.9928995
# [20,] 0.490 0.992545 0.9640123 0.9806605 0.9928995
# [21,] 0.495 0.993040 0.9640299 0.9820440 0.9933710
# [22,] 0.500 0.993040 0.9640458 0.9820440 0.9933710
# [23,] 0.505 0.993040 0.9640619 0.9820440 0.9933710
# [24,] 0.510 0.993020 0.9640354 0.9820020 0.9933520
# [25,] 0.515 0.993020 0.9640498 0.9820020 0.9933520
# [26,] 0.520 0.993020 0.9640640 0.9820020 0.9933520
# [27,] 0.525 0.993020 0.9640771 0.9820020 0.9933520
# [28,] 0.530 0.992030 0.9627394 0.9798479 0.9924090
# [29,] 0.535 0.993020 0.9641025 0.9820020 0.9933520
# [30,] 0.540 0.993020 0.9641144 0.9820020 0.9933520
# [31,] ⋮     ⋮        ⋮         ⋮         ⋮
# [32,] 0.700 0.992045 0.9633532 0.9798843 0.9924233
# [33,] 0.705 0.993035 0.9644884 0.9820333 0.9933662
# [34,] 0.710 0.993035 0.9644966 0.9820333 0.9933662
# [35,] 0.715 0.993035 0.9645038 0.9820333 0.9933662
# [36,] 0.720 0.993035 0.9647119 0.9820333 0.9933662
# [37,] 0.725 0.993035 0.9647191 0.9820333 0.9933662
# [38,] 0.730 0.993035 0.9647254 0.9820333 0.9933662
# [39,] 0.735 0.993015 0.9647883 0.9819885 0.9933472
# [40,] 0.740 0.993015 0.9647947 0.9819885 0.9933472
# [41,] 0.745 0.993035 0.9648415 0.9820333 0.9933662
# [42,] 0.750 0.993035 0.9647495 0.9820333 0.9933662
# [43,] 0.755 0.993035 0.9647551 0.9820333 0.9933662
# [44,] 0.760 0.993015 0.9646628 0.9819922 0.9933472
# [45,] 0.765 0.993015 0.9646685 0.9819922 0.9933472
# [46,] 0.770 0.993015 0.9646742 0.9819922 0.9933472
# [47,] 0.775 0.993015 0.9646799 0.9819922 0.9933472
# [48,] 0.780 0.993035 0.9647804 0.9820333 0.9933662
# [49,] 0.785 0.993035 0.9647852 0.9820333 0.9933662
# [50,] 0.790 0.993035 0.9647893 0.9820333 0.9933662
# [51,] 0.795 0.993035 0.9647936 0.9820333 0.9933662
# [52,] 0.800 0.993035 0.9646008 0.9820333 0.9933662
# [53,] 0.805 0.993035 0.9646049 0.9820333 0.9933662
# [54,] 0.810 0.993035 0.9646091 0.9820333 0.9933662
# [55,] 0.815 0.992540 0.9621523 0.9809513 0.9928948
# [56,] 0.820 0.992045 0.9621694 0.9795753 0.9924233
# [57,] 0.825 0.992045 0.9621858 0.9795753 0.9924233
# [58,] 0.830 0.992540 0.9624180 0.9809513 0.9928948
# [59,] 0.835 0.993035 0.9648238 0.9820333 0.9933662
# [60,] 0.840 0.993035 0.9648272 0.9820333 0.9933662
# [61,] 0.845 0.993035 0.9648304 0.9820333 0.9933662

# %%
results_lst_k <- matrix(, nrow = length(files_k), ncol = 5)
colnames(results_lst_k) <- c('K', rownames(table_lst_k[[1]]))
results_lst_k[,1] <- K
for(i in 1:length(files_k)) {
    if(is.null(table_lst_k[[i]]$x)){
        results_lst_k[i,2:5] <- NA
    } else{
    results_lst_k[i,2:5] <- table_lst_k[[i]]$x
    }
}

# %%
# ##Manually add
# results_lst_k[4,2:5] <- c(0.9610000, 0.9337315, 0.9369329, 0.9639048)

# %%
results_lst_d <- matrix(, nrow = length(files_d), ncol = 5)
colnames(results_lst_d) <- c('D', rownames(table_lst_d[[2]]))
results_lst_d[,1] <- D
for(i in 1:length(files_d)) {
    if(is.null(table_lst_d[[i]]$x)){
        results_lst_d[i,2:5] <- NA
    } else{
    results_lst_d[i,2:5] <- table_lst_d[[i]]$x
    }
}

# %%
# saveRDS(results_lst_mvr, '/home/bz234/project/Results/CyTOF/simulation/vary_mvr/mvr_all.rds')
saveRDS(results_lst_corr, '/home/bz234/project/Results/CyTOF/simulation/vary_corr/corr_all.rds')
# saveRDS(results_lst_k, '/home/bz234/project/Results/CyTOF/simulation/vary_k/k_all_N_changed.rds')

# %%
results_lst_mvr <- readRDS('/home/bz234/project/Results/CyTOF/simulation/vary_mvr/mvr_all.rds')
results_lst_corr <- readRDS('/home/bz234/project/Results/CyTOF/simulation/vary_corr/corr_all.rds')
results_lst_k <- readRDS('/home/bz234/project/Results/CyTOF/simulation/vary_k/k_all_N_changed.rds')

# %%
results_lst_k
# Out:
#       K  accu      cos_sim   ari       nmi
#  [1,]  3 0.1763200 0.2215484 1.0000000 0.4020228
#  [2,]  4 0.9999963 0.9870412 0.9999899 0.9999968
#  [3,]  5 1.0000000 0.9866983 1.0000000 1.0000000
#  [4,]  6 0.9995050 0.9741611 0.9991143 0.9995419
#  [5,]  7 0.9999700 0.9831901 0.9999169 0.9999718
#  [6,]  8 0.9998144 0.9777679 0.9996530 0.9998232
#  [7,]  9 0.9958733 0.9488869 0.9933480 0.9960381
#  [8,] 10 0.9994060 0.9689538 0.9987656 0.9994264
#  [9,] 11 0.9998636 0.9761880 0.9997723 0.9998677
# [10,] 12 0.9991200 0.9723447 0.9981030 0.9991433
# [11,] 13 0.9996481 0.9745941 0.9992900 0.9996564
# [12,] 14 0.9996796 0.9823962 0.9994877 0.9996865
# [13,] 15 0.9966000 0.9585929 0.9928497 0.9966662
# [14,] 16 0.9988750 0.9672043 0.9972345 0.9988951
# [15,] 17 0.8997618 0.8829795 0.9214786 0.9014101
# [16,] 18 0.9992500 0.9811560 0.9984298 0.9992614
# [17,] 19 0.9974738 0.9685965 0.9954417 0.9975096
# [18,] 20 0.9991000 0.9801647 0.9981320 0.9991119
# [19,] 21 0.9986429 0.9674041 0.9971965 0.9986597
# [20,] 22 0.8990932 0.8710632 0.9621164 0.9002749
# [21,] 23 0.8745190 0.8559220 0.9125831 0.8759061
# [22,] 24 0.9302500 0.8985768 0.9622190 0.9309798
# [23,] 25 0.9948401 0.9635073 0.9906381 0.9948913
# [24,] 26 0.9750764 0.9386430 0.9706217 0.9753117
# [25,] 27 0.9923333 0.9415517 0.9856672 0.9924023
# [26,] 28 0.9995714 0.9710467 0.9994115 0.9995751
# [27,] 29 0.9806548 0.9406182 0.9747673 0.9808137
# [28,] 30 0.6667000 0.6582348 0.6565518 0.6693219
# [29,] 31 0.9813229 0.9528898 0.9761708 0.9814638
# [35,] 0.870 0.9835  0.9495268 0.9657392 0.9842847
# [36,] 0.875 0.9835  0.9495509 0.9657392 0.9842847
# [37,] 0.880 0.9835  0.9495738 0.9657392 0.9842847
# [38,] 0.885 0.9835  0.9495970 0.9657392 0.9842847
# [39,] 0.890 0.9835  0.9496192 0.9657392 0.9842847
# [40,] 0.895 0.9835  0.9496408 0.9657392 0.9842847
# [41,] 0.900 0.9835  0.9513709 0.9652830 0.9842847
# [42,] 0.905 0.9835  0.9513821 0.9652830 0.9842847
# [43,] 0.910 0.9835  0.9497041 0.9657392 0.9842847
# [44,] 0.915 0.9835  0.9497247 0.9657392 0.9842847
# [45,] 0.920 0.9835  0.9497446 0.9657392 0.9842847
# [46,] 0.925 0.9835  0.9497646 0.9657392 0.9842847
# [47,] 0.930 0.9835  0.9497835 0.9657392 0.9842847
# [48,] 0.935 0.9835  0.9498027 0.9657392 0.9842847
# [49,] 0.940 0.9830  0.9514535 0.9641305 0.9838085
# [50,] 0.945 0.9830  0.9514633 0.9641305 0.9838085
# [51,] 0.950 0.9830  0.9514728 0.9641305 0.9838085
# [52,] 0.955 0.9830  0.9514822 0.9641305 0.9838085
# [53,] 0.960 0.9830  0.9514910 0.9641305 0.9838085
# [54,] 0.965 0.9830  0.9515000 0.9641305 0.9838085
# [55,] 0.970 0.9830  0.9515089 0.9641305 0.9838085
# [56,] 0.975 0.9830  0.9515177 0.9641305 0.9838085
# [57,] 0.980 0.9830  0.9515259 0.9641305 0.9838085
# [58,] 0.985 0.9830  0.9515344 0.9641305 0.9838085
# [59,] 0.990 0.9830  0.9515427 0.9641305 0.9838085
# [60,] 0.995 0.9830  0.9500072 0.9647035 0.9838085
# [61,] 1.000 0.9830  0.9500221 0.9647035 0.9838085

# %%
results_mvr <- melt(as.data.frame(results_lst_mvr), id.vars = 'mean_var_ratio', variable.name = 'Metrics')
p_mvr <- ggplot(results_mvr, aes(mean_var_ratio,value)) + 
    geom_point(aes(colour = Metrics), shape = 4) +
    labs(y = 'Annotation Metric', x = 'Mean variance ratio', title = 'Vary mean variance ratio') + 
    geom_line(aes(color = Metrics, linetype = Metrics), size=2) +
    theme(axis.text=element_text(size=12),
    axis.title=element_text(size=14,face="bold"),
    plot.title = element_text(size=14))
p_mvr
# Out:
# Error in as.data.frame(results_lst_mvr): object 'results_lst_mvr' not found
# Traceback:
#
# 1. melt(as.data.frame(results_lst_mvr), id.vars = "mean_var_ratio",
#  .     variable.name = "Metrics")
# 2. as.data.frame(results_lst_mvr)

# %%
results_corr <- melt(as.data.frame(results_lst_corr), id.vars = 'corr', variable.name = 'Metrics')
p_corr <- ggplot(results_corr, aes(corr,value)) + 
    geom_point(aes(colour = Metrics), shape = 4) +
    labs(y = 'Annotation Metric', x = 'Corr', title = 'Vary correlation') + 
    geom_line(aes(color = Metrics, linetype = Metrics), size=2) +
    theme(axis.text=element_text(size=12),
    axis.title=element_text(size=14,face="bold"),
    plot.title = element_text(size=14)) +
    ylim(0.6, 1)
p_corr
# Out:
# plot without title

# %%
results_lst <- rbind(results_lst_corr[1:length(seq(.1, 0.5, 0.005)),], 
    results_lst_corr_all[(length(seq(.1, 0.5, 0.005)) + 1):length(seq(.1, 0.75, 0.005)),])
results_lst <- melt(as.data.frame(results_lst), id.vars = 'corr', variable.name = 'Metrics')
p_corr <- ggplot(results_lst, aes(corr,value)) + 
    geom_point(aes(colour = Metrics), shape = 4) +
    labs(y = 'Annotation Metric', x = 'Corr', title = 'Vary correlation') + 
    geom_line(aes(color = Metrics, linetype = Metrics), size=2) +
    theme(axis.text=element_text(size=12),
    axis.title=element_text(size=14,face="bold"),
    plot.title = element_text(size=14))
p_corr
# Out:
# plot without title

# %%
rbind(results_lst_corr[])

# %%
results_corr <- melt(as.data.frame(results_lst_corr), id.vars = 'corr', variable.name = 'Metrics')
p_corr <- ggplot(results_corr, aes(corr,value)) + 
    geom_point(aes(colour = Metrics), shape = 4) +
    labs(y = 'Annotation Metric', x = 'Corr', title = 'Vary correlation') + 
    geom_line(aes(color = Metrics, linetype = Metrics), size=2) +
    theme(axis.text=element_text(size=12),
    axis.title=element_text(size=14,face="bold"),
    plot.title = element_text(size=14))
p_corr
# Out:
# plot without title

# %%
results_corr <- melt(as.data.frame(results_lst_corr), id.vars = 'corr', variable.name = 'Metrics')
p_corr <- ggplot(results_corr, aes(corr,value)) + 
    geom_point(aes(colour = Metrics), shape = 4) +
    labs(y = 'Annotation Metric', x = 'Corr', title = 'Vary correlation') + 
    geom_line(aes(color = Metrics, linetype = Metrics), size=2) +
    theme(axis.text=element_text(size=12),
    axis.title=element_text(size=14,face="bold"),
    plot.title = element_text(size=14))
p_corr
# Out:
# plot without title

# %%
results_lst_k
# Out:
#       K  accu      cos_sim   ari       nmi
#  [1,]  3 0.1763200 0.2215484 1.0000000 0.4020228
#  [2,]  4 0.9999963 0.9870412 0.9999899 0.9999968
#  [3,]  5 1.0000000 0.9866983 1.0000000 1.0000000
#  [4,]  6 0.9995050 0.9741611 0.9991143 0.9995419
#  [5,]  7 0.9999700 0.9831901 0.9999169 0.9999718
#  [6,]  8 0.9998144 0.9777679 0.9996530 0.9998232
#  [7,]  9 0.9958733 0.9488869 0.9933480 0.9960381
#  [8,] 10 0.9994060 0.9689538 0.9987656 0.9994264
#  [9,] 11 0.9998636 0.9761880 0.9997723 0.9998677
# [10,] 12 0.9991200 0.9723447 0.9981030 0.9991433
# [11,] 13 0.9996481 0.9745941 0.9992900 0.9996564
# [12,] 14 0.9996796 0.9823962 0.9994877 0.9996865
# [13,] 15 0.9966000 0.9585929 0.9928497 0.9966662
# [14,] 16 0.9988750 0.9672043 0.9972345 0.9988951
# [15,] 17 0.8997618 0.8829795 0.9214786 0.9014101
# [16,] 18 0.9992500 0.9811560 0.9984298 0.9992614
# [17,] 19 0.9974738 0.9685965 0.9954417 0.9975096
# [18,] 20 0.9991000 0.9801647 0.9981320 0.9991119
# [19,] 21 0.9986429 0.9674041 0.9971965 0.9986597
# [20,] 22 0.8990932 0.8710632 0.9621164 0.9002749
# [21,] 23 0.8745190 0.8559220 0.9125831 0.8759061
# [22,] 24 0.9302500 0.8985768 0.9622190 0.9309798
# [23,] 25 0.9948401 0.9635073 0.9906381 0.9948913
# [24,] 26 0.9750764 0.9386430 0.9706217 0.9753117
# [25,] 27 0.9923333 0.9415517 0.9856672 0.9924023
# [26,] 28 0.9995714 0.9710467 0.9994115 0.9995751
# [27,] 29 0.9806548 0.9406182 0.9747673 0.9808137
# [28,] 30 0.6667000 0.6582348 0.6565518 0.6693219
# [29,] 31 0.9813229 0.9528898 0.9761708 0.9814638
# [30,] 32 0.9290770 0.8960266 0.8933175 0.9295912
# [31,] 33 0.9975909 0.9678266 0.9957308 0.9976077
# [32,] 34 0.9958971 0.9603512 0.9929802 0.9959247
# [33,] 35 0.9094416 0.8812816 0.9022738 0.9100282
# [34,] 36 0.9772917 0.9285712 0.9649336 0.9774337
# [35,] 37 0.9670004 0.9347862 0.9545446 0.9671999
# [36,] 38 0.9493546 0.9076968 0.9382809 0.9496506
# [37,] 39 0.9541538 0.8892203 0.9295741 0.9544133
# [38,] 40 0.9799753 0.9324312 0.9686584 0.9800851

# %%
results_k <- melt(as.data.frame(results_lst_k[-c(1,28),]), id.vars = 'K', variable.name = 'Metrics')
p_k <- ggplot(results_k, aes(K,value)) + 
    geom_point(aes(colour = Metrics), shape = 4) +
    labs(y = 'Annotation Metric', x = 'K', title = 'Vary K') + 
    geom_line(aes(color = Metrics, linetype = Metrics), size=2) +
    theme(axis.text=element_text(size=12),
    axis.title=element_text(size=14,face="bold"),
    plot.title = element_text(size=14))
p_k
# Out:
# plot without title

# %%
results_k <- melt(as.data.frame(results_lst_k), id.vars = 'K', variable.name = 'Metrics')
p_k <- ggplot(results_k, aes(K,value)) + 
    geom_point(aes(colour = Metrics), shape = 4) +
    labs(y = 'Annotation Metric', x = 'K', title = 'Vary K') + 
    geom_line(aes(color = Metrics, linetype = Metrics), size=2) +
    theme(axis.text=element_text(size=12),
    axis.title=element_text(size=14,face="bold"),
    plot.title = element_text(size=14))
p_k
# Out:
# plot without title

# %%
results_lst_k
# Out:
#       K  accu       cos_sim    ari       nmi
#  [1,]  3 0.99450000 0.97528844 0.9818907 0.99600710
#  [2,]  4 0.97825272 0.96326840 0.9414999 0.98153799
#  [3,]  5 0.88538854 0.87988014 0.8086282 0.89696285
#  [4,]  6 0.90100000 0.88331377 0.8826869 0.90837383
#  [5,]  7 0.96143133 0.93435004 0.9291017 0.96368093
#  [6,]  8 0.96249766 0.92961999 0.9251958 0.96428119
#  [7,]  9 0.78266667 0.77594732 0.7018696 0.79134256
#  [8,] 10 0.74681266 0.74004462 0.8116569 0.75548432
#  [9,] 11 0.01336424 0.05918353 0.6447952 0.04285656
# [10,] 12 0.73312500 0.75672354 0.7584769 0.74018330
# [11,] 13 0.65882081 0.66339791 0.6017591 0.66689482
# [12,] 14 0.64566592 0.63238253 0.6482000 0.65323946
# [13,] 15 0.72230000 0.72659703 0.5889438 0.72770362
# [14,] 16 0.42392425 0.46859336 0.5453154 0.43419877
# [15,] 17 0.43254213 0.43072744 0.5666623 0.44187353
# [16,] 18 0.18750000 0.22270872 0.1690273 0.19988242
# [17,] 19 0.37988474 0.40348702 0.4692522 0.38868302
# [18,] 20 0.58958974 0.62316062 0.5074437 0.59503278
# [19,] 21 0.51285714 0.54441260 0.4647682 0.51891817
# [20,] 22 0.63564464 0.61802524 0.5410726 0.63991135
# [21,] 23 0.22748321 0.24787761 0.2685393 0.23602267
# [22,] 24 0.41187500 0.43359507 0.4325219 0.41802828
# [23,] 25 0.54508910 0.54906530 0.5095413 0.54960491
# [24,] 26 0.53493336 0.53565142 0.5066925 0.53932339
# [25,] 27 0.46783333 0.51432627 0.4616451 0.47262000
# [26,] 28 0.38002893 0.40960493 0.3460737 0.38535263
# [27,] 29 0.49464646 0.51340068 0.4478753 0.49879653
# [28,] 30 0.41150000 0.41822007 0.3852444 0.41612946
# [29,] 31 0.46068612 0.45750175 0.4029414 0.46475623
# [30,] 32 0.45047579 0.46921289 0.3726314 0.45446003
# [31,] 33 0.40681818 0.42104953 0.3515554 0.41095545
# [32,] 34 0.07107248 0.11108796 0.1491979 0.07731289
# [33,] 35 0.31346162 0.32844915 0.3025584 0.31790900
# [34,] 36 0.26925000 0.30032217 0.2722729 0.27381974
# [35,] 37 0.21972676 0.25244902 0.2799552 0.22444195
# [36,] 38 0.37997868 0.41153235 0.3356327 0.38360287
# [37,] 39 0.32796154 0.35708590 0.3047640 0.33176474
# [38,] 40 0.44005700 0.45606159 0.3625467 0.44312762

# %%
results_k <- melt(as.data.frame(results_lst_k[1:23,]), id.vars = 'K', variable.name = 'Metrics')
ggplot(results_k, aes(K,value)) + 
    geom_point(aes(colour = Metrics), shape = 4) +
    labs(y = 'Annotation Metric', x = 'K', title = 'Vary K') + 
    geom_line(aes(color = Metrics, linetype = Metrics), size=2) +
    theme(axis.text=element_text(size=12),
    axis.title=element_text(size=14,face="bold"),
    plot.title = element_text(size=14))
# Out:
# plot without title

# %%
pll <- plot_grid(plotlist = list(p_mvr, p_corr, p_k), ncol=3)
ggsave('/home/bz234/project/Results/CyTOF/simulation/vary_mvr_corr_k_plot.png', pll, width = 15, height = 4)
# Out:
# Warning message:
# “Removed 4 rows containing missing values (geom_point).”

# %%
# results_d <- melt(as.data.frame(results_lst_d), id.vars = 'D', variable.name = 'Metrics')
# p_d <- ggplot(results_d, aes(D,value)) + 
#     geom_point(aes(colour = Metrics), shape = 4) +
#     labs(y = 'Annotation Metric', x = 'D', title = 'Vary D') + 
#     geom_line(aes(color = Metrics, linetype = Metrics), size=2) +
#     theme(axis.text=element_text(size=12),
#     axis.title=element_text(size=14,face="bold"),
#     plot.title = element_text(size=14))
# p_d
# Out:
# Warning message:
# “Removed 32 rows containing missing values (geom_point).”
# Warning message:
# “Removed 8 row(s) containing missing values (geom_path).”
# plot without title
